# %%
 import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
z=pd.read_csv(r"C:\Users\sowjanya\Desktop\CSV Files\WEB SCRAPING PROJECT\Smartprix Tablets.csv")

# %%
z.head()     # Smartprix
# Out:
#    Unnamed: 0   Brands Model  Processor  RAM  ROM  Battery  Screen_Size  \
# 0           0   Realme   Pad       2.20    4   64     8340        10.95
# 1           1    Apple  iPad       2.00    8   64     8600        10.20
# 2           2   Xiaomi    Mi       2.20    4   64     5299        10.28
# 3           3  OnePlus   Pad       2.65    6  256    10090        10.28
# 4           4   Xiaomi    Mi      65.00    6  128     8720        10.28
#
#    Prices
# 0   25999
# 1   28990
# 2   39999
# 3   39999
# 4   29107

# %%
y=pd.read_csv(r"C:\Users\sowjanya\Desktop\CSV Files\WEB SCRAPING PROJECT\Tablets.csv")

# %%
y.head()      # Flipkart
# Out:
#    Unnamed: 0   Brands   Model         Colors  RAM  ROM  Battery  Screen_Size  \
# 0           0  SAMSUNG  Galaxy          Blue)    4   64     7040        26.42
# 1           1  SAMSUNG  Galaxy  Mystic Black)    6  128    10090        31.50
# 2           2   realme     Pad          Grey)    4   64     7100        26.42
# 3           3   realme     Pad          Gold)    4   64     7100        26.42
# 4           4   realme     Pad          Grey)    3   32     7100        26.42
#
#    Prices
# 0   24999
# 1   47999
# 2   16499
# 3   16499
# 4   11999

# %%
a=z[z['Prices']<=15000]      # SMARTPRIX

# %%
a
# Out:
#      Unnamed: 0  Brands Model  Processor  RAM  ROM  Battery  Screen_Size  \
# 13           13  Realme   Pad       2.20    3  128     7100        10.61
# 41           41  Realme   Pad       2.96    6   32     7100        10.28
# 69           69  Realme   Pad       3.20    4  128     8340        10.36
# 97           97  Realme   Pad      65.00    4   64     5299        10.28
# 125         125  Realme   Pad       3.20    4   64     5299        10.28
# 153         153  Realme   Pad       2.20    4   64     5299        10.28
# 181         181  Realme   Pad       2.20    8  128     8600        10.58
# 209         209  Realme   Pad       2.20    4  128     8340        10.28
# 237         237  Realme   Pad      96.00    6   64     8720        10.28
# 265         265  Realme   Pad       2.00    4   64     5299        10.28
# 293         293  Realme   Pad      96.00    6  128     8720        10.61
# 321         321  Realme   Pad       2.20    4   64     5299        10.28
# ...

# %%
b=y[y['Prices']<=15000]      # FLIPKART

# %%
b
# Out:
#      Unnamed: 0   Brands   Model  \
# 4             4   realme     Pad
# 5             5   Lenovo     Tab
# 7             7   realme     Pad
# 11           11  SAMSUNG  Galaxy
# 12           12   realme     Pad
# ..          ...      ...     ...
# 713         713   Lenovo     Tab
# 715         715  SAMSUNG  Galaxy
# 716         716        I    Kall
# 717         717        I    Kall
# 718         718  Wishtel     Ira
#
#                                                 Colors  RAM  ROM  Battery  \
# 4                                                Grey)    3   32     7100
# 5                                       Platinum Grey)    4  128     5000
# 7                                                Blue)    4   64     6400
# 11                                             Silver)    6   32     7700
# 12                                               Grey)    3   64     7040
# ..                                                 ...  ...  ...      ...
# ...

# %%
z.describe()
# Out:
#        Unnamed: 0   Processor         RAM         ROM       Battery  \
# count   700.00000  700.000000  700.000000  700.000000    700.000000
# mean    349.50000   14.239643    5.035714  101.714286   7192.142857
# std     202.21688   29.406999    1.842942   61.151830   1645.985942
# min       0.00000    2.000000    3.000000   32.000000   5299.000000
# 25%     174.75000    2.000000    4.000000   64.000000   5299.000000
# 50%     349.50000    2.200000    4.000000   64.000000   7100.000000
# 75%     524.25000    3.050000    6.000000  128.000000   8340.000000
# max     699.00000   96.000000   12.000000  256.000000  11200.000000
#
#        Screen_Size         Prices
# count   700.000000     700.000000
# mean     10.639286   29747.928571
# std       0.871812   18496.569786
# min      10.200000   14999.000000
# 25%      10.280000   19874.000000
# 50%      10.320000   25999.000000
# 75%      10.587500   29107.000000
# max      14.600000  111999.000000

# %%
y.describe()
# Out:
#        Unnamed: 0         RAM         ROM       Battery  Screen_Size  \
# count  720.000000  720.000000  720.000000    720.000000   720.000000
# mean   359.500000    3.238889  105.218056   4147.213889    25.683458
# std    207.990384    2.461077  119.586241   2057.654757     5.109022
# min      0.000000    1.000000    1.000000   2500.000000    12.700000
# 25%    179.750000    2.000000   32.000000   2685.000000    21.080000
# 50%    359.500000    2.000000   64.000000   2685.000000    25.910000
# 75%    539.250000    4.000000  128.000000   5100.000000    27.940000
# max    719.000000   16.000000  512.000000  10200.000000    37.080000
#
#               Prices
# count     720.000000
# mean    47063.995833
# std     44200.037126
# min      3514.000000
# 25%     11999.000000
# 50%     32499.000000
# 75%     68900.000000
# max    236900.000000

# %% [markdown]
# # Clalulating the Oultliers Present wrt Prices for both SmartPrix and Flipkart

# %%
x=np.percentile(z["Prices"],[25,50,75])    # SmartPrix

# %%
x
# Out:
# array([19874., 25999., 29107.])

# %%
q1=x[0]
q1
# Out:
# 19874.0

# %%
q2=x[1]
q2
# Out:
# 25999.0

# %%
q3=x[2]
q3
# Out:
# 29107.0

# %%
iqr=q3-q1
iqr
# Out:
# 9233.0

# %%
lb=q1-(1.5*iqr)
lb
# Out:
# 6024.5

# %%
ub=q3+(1.5*iqr)
ub
# Out:
# 42956.5

# %%
z.loc[z["Prices"]<lb]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Brands, Model, Processor, RAM, ROM, Battery, Screen_Size, Prices]
# Index: []

# %%
c=z.loc[z["Prices"]>ub]
c
# Out:
#      Unnamed: 0   Brands   Model  Processor  RAM  ROM  Battery  Screen_Size  \
# 16           16    Apple    iPad       2.20    4   64     5299        10.28
# 19           19  Samsung  Galaxy       2.20    6   64     8720        10.28
# 44           44    Apple    iPad       3.00    4   64     8340        10.28
# 47           47  Samsung  Galaxy       2.20    6  256     8720        10.28
# 72           72    Apple    iPad       2.84    8  256     8600        10.40
# 75           75  Samsung  Galaxy      96.00    4  128     8200        10.28
# 100         100    Apple    iPad       2.84    6  256     8000        10.28
# 103         103  Samsung  Galaxy      96.00    4  256     7040        10.28
# 128         128    Apple    iPad       2.20    4  128     5299        10.28
# 131         131  Samsung  Galaxy      84.00    4   64     7100        10.50
# 156         156    Apple    iPad       2.65    4   64     7040        10.50
# ...

# %%
w=np.percentile(y["Prices"],[25,50,75])     # Flipkart

# %%
w
# Out:
# array([11999., 32499., 68900.])

# %%
q1=w[0]
q1
# Out:
# 11999.0

# %%
q2=w[1]
q2
# Out:
# 32499.0

# %%
q3=w[2]
q3
# Out:
# 68900.0

# %%
iqr=q3-q1
iqr
# Out:
# 56901.0

# %%
lb=q1-(1.5*iqr)
lb
# Out:
# -73352.5

# %%
ub=q3+(1.5*iqr)
ub
# Out:
# 154251.5

# %%
y.loc[y["Prices"]<lb]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Brands, Model, Colors, RAM, ROM, Battery, Screen_Size, Prices]
# Index: []

# %%
d=y.loc[y["Prices"]>ub]
d
# Out:
#      Unnamed: 0 Brands Model  \
# 98           98  APPLE  iPad
# 125         125  APPLE  iPad
# 126         126  APPLE  iPad
# 139         139  APPLE  iPad
# 141         141  APPLE  iPad
# 152         152  APPLE  iPad
# 160         160  APPLE  iPad
# 165         165  APPLE  iPad
# 170         170  APPLE  iPad
# 171         171  APPLE  iPad
# 174         174  APPLE  iPad
# 178         178  APPLE  iPad
# 188         188  APPLE  iPad
# 190         190  APPLE  iPad
# 193         193  APPLE  iPad
# 196         196  APPLE  iPad
# 215         215  APPLE  iPad
# 216         216  APPLE  iPad
# 390         390  APPLE  iPad
# 434         434  APPLE  iPad
# 457         457  APPLE  iPad
# 485         485  APPLE  iPad
# 488         488  APPLE  iPad
# 613         613  APPLE  iPad
# 614         614  APPLE  iPad
# 642         642  APPLE  iPad
# 654         654  APPLE  iPad
#
#                                                 Colors  RAM  ROM  Battery  \
# ...

# %% [markdown]
# # From the above data I can say that:
# # 1) SmartPrix is caontaing 50 Outliers of two Brands "Apple" and "Samsung"
# # 2) Flipkart is containing 27 Outliers of one Brand "Apple"

# %%
z.boxplot()
# Out:
# <AxesSubplot:>

# %%
y.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Visually we can say that SmartPrix and Flipkart both are containing Outliers wrt Prices

# %% [markdown]
# # Variation of Prices wrt RAM for SmartPrix and Flipkart

# %%
sns.scatterplot(data=z,x="RAM",y="Prices")
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='Prices'>

# %%
sns.scatterplot(data=y,x="RAM",y="Prices")
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='Prices'>

# %% [markdown]
# # The Variation in Prices are not that much affected even there is an increase in RAM but we can observe some outliers wrt SmartPrix and Flipkart

# %% [markdown]
# # Scatter Plot wrt RAM & ROM

# %%
sns.scatterplot(data=z,x="RAM",y="Prices",hue="Brands")
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='Prices'>

# %%
sns.scatterplot(data=y,x="RAM",y="Prices",hue="Brands")
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='Prices'>

# %% [markdown]
# # Distribution Plot wrt RAM & ROM

# %%
sns.distplot(z["RAM"])
# Out:
# C:\Users\sowjanya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='RAM', ylabel='Density'>

# %%
sns.distplot(y["RAM"])
# Out:
# C:\Users\sowjanya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='RAM', ylabel='Density'>

# %% [markdown]
# # We can observe that in SmartPrix most of the Tabs are containing 4GB RAM and in Flipkart most of the Tabs are containing 2 GB RAM

# %%
z["Brands"].unique()
# Out:
# array(['Realme', 'Apple', 'Xiaomi', 'OnePlus', 'Nokia', 'Samsung', 'Vivo',
#        'Motorola', 'Lenovo'], dtype=object)

# %%
y["Brands"].unique()
# Out:
# array(['SAMSUNG', 'realme', 'Lenovo', 'MOTOROLA', 'APPLE', 'REDMI',
#        'Honor', 'I', 'Oppo', 'TCL', 'DOMO', 'acer', 'Alcatel', 'ankikrit',
#        'Nokia', 'FUSION5', 'Swipe', 'Huawei', 'Pebble', 'Wishtel',
#        'Contixo', 'LAVA', 'iball', 'Elevn', 'DELL', 'VIZIO', 'Heatz',
#        'ASUS', 'Panasonic', 'Apple', 'Smartbeats', 'HP', 'Samsung',
#        'Micromax', 'CG'], dtype=object)

# %%
sns.displot(data=z,x="RAM",hue="Brands",kind="kde")      # SmartPrix

# %% [markdown]
# # Most of the Tabs are containing 2GB to 6GB RAM's and small cluster contains 12GB RAM
# # Xiaomi Brand is distributed more at 4GB RAM when compare to other Brands

# %%
sns.displot(data=y,x="RAM",hue="Brands",kind="kde")      # Flipkart
# Out:
# C:\Users\sowjanya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Most of the Tabs are containing 2GB to 4GB RAM's
# # Redmi Brand is distributed more at 3GB RAM when compare to other Brands

# %%
sns.displot(data=z,x="ROM",hue="Brands",kind="kde")

# %% [markdown]
# # Most of the Tabs are containing 64GB to 128GB ROM's and small cluster contains 256GB ROM
# # Xiaomi Brand is distributed more at 64GB ROM when compare to other Brands

# %%
sns.displot(data=y,x="ROM",hue="Brands",kind="kde")
# Out:
# C:\Users\sowjanya\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Most of the Tabs are containing 32GB to 128GB ROM's and small cluster contains 256 GB ROM and 512GB ROM
# # Redmi Brand is distributed more at 64GB ROM when compare to other Brands

# %%
sns.barplot(x=z["Brands"].unique(),y=z["Brands"].value_counts())
# Out:
# <AxesSubplot:ylabel='Brands'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=y["Brands"].unique()[0:10],y=y["Brands"].value_counts()[0:10])
# Out:
# <AxesSubplot:ylabel='Brands'>

# %%
sns.barplot(x=z["RAM"],y=z["Prices"])      # SmartPrix
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='Prices'>

# %%
sns.barplot(x=y["RAM"],y=y["Prices"])     # Flipkart
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='Prices'>

# %%
sns.barplot(x=z["ROM"],y=z["Prices"])
# Out:
# <AxesSubplot:xlabel='ROM', ylabel='Prices'>

# %%
sns.barplot(x=y["ROM"],y=y["Prices"])
# Out:
# <AxesSubplot:xlabel='ROM', ylabel='Prices'>

# %% [markdown]
# # To find the count of each Brand

# %%
sns.countplot(data=z,x='Brands')     # SmartPrix
# Out:
# <AxesSubplot:xlabel='Brands', ylabel='count'>

# %% [markdown]
# # SmartPrix contains more Xiaomi Brands then Realme and Smasung has equal number when compared to remaining Brands

# %%
plt.figure(figsize=(10,15))
g=sns.countplot(data=y,x="Brands")
plt.xticks(rotation=90)
plt.show                                         # Flipkart
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Flipkart contains more Apple Brands then Smasung and Lenovo when compared to remaining Brands

# %%
sns.countplot(data=z,x='RAM')         # SmartPrix
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='count'>

# %% [markdown]
# # SmartPrix Tabs contains more 4GB RAM when compare to 6,8,3 and 12GB RAM's

# %%
sns.countplot(data=y,x='RAM')
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='count'>

# %% [markdown]
# # Flipkart Tabs contains more 2GB RAM when compare to remaining RAM's

# %%
sns.countplot(data=z,x='ROM')
# Out:
# <AxesSubplot:xlabel='ROM', ylabel='count'>

# %% [markdown]
# # SmartPrix Tabs contains more 64GB ROM when compare to 32,128 and 256GB ROM's

# %%
sns.countplot(data=y,x='ROM')
# Out:
# <AxesSubplot:xlabel='ROM', ylabel='count'>

# %% [markdown]
# # Flipkart Tabs contains more 64GB ROM when compare to remaining ROM's

# %%
sns.countplot(data=z,x='Battery')
# Out:
# <AxesSubplot:xlabel='Battery', ylabel='count'>

# %% [markdown]
# # SmartPrix Tabs contains more 5299 mAh when compare to remaining mAh's

# %%
sns.countplot(data=y,x='Battery')
# Out:
# <AxesSubplot:xlabel='Battery', ylabel='count'>

# %% [markdown]
# # Flipkart Tabs contains more 5299 mAh when compare to remaining mAh's

# %%
sns.countplot(data=z,x='Screen_Size')      # SmartPrix
# Out:
# <AxesSubplot:xlabel='Screen_Size', ylabel='count'>

# %% [markdown]
# # SmartPrix Tabs contains more 10.28 inches of Screen Size when compare to remaining Screen Size

# %%
sns.countplot(data=y,x='Screen_Size')         # Flipkart
# Out:
# <AxesSubplot:xlabel='Screen_Size', ylabel='count'>

# %%
# Flipkart Tabs contains more inches when compare to remaining inches

# %%
sns.pairplot(z)

# %%
sns.pairplot(y)

# %%
z["Brands"].unique()
# Out:
# array(['Realme', 'Apple', 'Xiaomi', 'OnePlus', 'Nokia', 'Samsung', 'Vivo',
#        'Motorola', 'Lenovo'], dtype=object)

# %%
y["Brands"].unique()
# Out:
# array(['SAMSUNG', 'realme', 'Lenovo', 'MOTOROLA', 'APPLE', 'REDMI',
#        'Honor', 'I', 'Oppo', 'TCL', 'DOMO', 'acer', 'Alcatel', 'ankikrit',
#        'Nokia', 'FUSION5', 'Swipe', 'Huawei', 'Pebble', 'Wishtel',
#        'Contixo', 'LAVA', 'iball', 'Elevn', 'DELL', 'VIZIO', 'Heatz',
#        'ASUS', 'Panasonic', 'Apple', 'Smartbeats', 'HP', 'Samsung',
#        'Micromax', 'CG'], dtype=object)
