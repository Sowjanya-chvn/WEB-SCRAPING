# %%
###"C:\Users\Subhadra\Desktop\Smartprix_Tablets.csv"

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tablet=pd.read_csv(r"C:\Users\Subhadra\Desktop\Smartprix_Tablets.csv")

# %%
tabletF=pd.read_csv(r"C:\Users\Subhadra\Desktop\Tablets.csv")

# %%
tablet
# Out:
#      Unnamed: 0    Brands   Model  Processor  RAM  ROM  Battery  Screen_Size  \
# 0             0    Realme     Pad       2.20    4   64     8340        10.95
# 1             1     Apple    iPad       2.00    8   64     8600        10.20
# 2             2    Xiaomi      Mi       2.20    4   64     5299        10.28
# 3             3   OnePlus     Pad       2.65    6  256    10090        10.28
# 4             4    Xiaomi      Mi      65.00    6  128     8720        10.28
# ..          ...       ...     ...        ...  ...  ...      ...          ...
# 695         695    Xiaomi      Mi       2.00    4  256     5299        10.28
# 696         696   Samsung  Galaxy       2.96    6   64     7100        10.90
# 697         697  Motorola    Moto      96.00    6  128     8720        10.40
# 698         698    Lenovo     Tab       3.20    4  128     5299        10.28
# 699         699    Xiaomi   Redmi       2.00   12  256    11200        14.60
#
#      Prices
# 0     25999
# 1     28990
# ...

# %%
tablet.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
tablet
# Out:
#        Brands   Model  Processor  RAM  ROM  Battery  Screen_Size  Prices
# 0      Realme     Pad       2.20    4   64     8340        10.95   25999
# 1       Apple    iPad       2.00    8   64     8600        10.20   28990
# 2      Xiaomi      Mi       2.20    4   64     5299        10.28   39999
# 3     OnePlus     Pad       2.65    6  256    10090        10.28   39999
# 4      Xiaomi      Mi      65.00    6  128     8720        10.28   29107
# ..        ...     ...        ...  ...  ...      ...          ...     ...
# 695    Xiaomi      Mi       2.00    4  256     5299        10.28   29107
# 696   Samsung  Galaxy       2.96    6   64     7100        10.90   25999
# 697  Motorola    Moto      96.00    6  128     8720        10.40   19999
# 698    Lenovo     Tab       3.20    4  128     5299        10.28   23999
# 699    Xiaomi   Redmi       2.00   12  256    11200        14.60   19499
#
# [700 rows x 8 columns]

# %%
tabletF.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
tabletF
# Out:
#       Brands   Model                                          Colors  RAM  \
# 0    SAMSUNG  Galaxy                                           Blue)    4
# 1    SAMSUNG  Galaxy                                   Mystic Black)    6
# 2     realme     Pad                                           Grey)    4
# 3     realme     Pad                                           Gold)    4
# 4     realme     Pad                                           Grey)    3
# ..       ...     ...                                             ...  ...
# 715  SAMSUNG  Galaxy                                          Black)    1
# 716        I    Kall                                          Black)    6
# 717        I    Kall                                          White)    2
# 718  Wishtel     Ira                                          Black)    4
# 719    APPLE    iPad  6th Gen) 512 GB ROM 12.9 inch with Wi-Fi Only     1
#
#      ROM  Battery  Screen_Size  Prices
# 0     64     7040        26.42   24999
# ...

# %%
sns.heatmap(tablet.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Highest Positive Correlation is maintained between Battery and RAM and
# # Slight Positive Correlation is maintained between Battery and Screen Size for SmartPrix Tabs

# %%
sns.heatmap(tabletF.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Highest Positive Correlation is maintained between Screen Size and Price and
# # Slight Positive Correlation is maintained between Battery and RAM for Flipkart Tabs
